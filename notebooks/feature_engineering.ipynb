# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.impute import SimpleImputer
from xverse.transformer import WOE

# %%
df = pd.read_csv('../data/data.csv')

# %%
df_fe = df.copy()

# %%
df_fe.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory    ChannelId   Amount  Value  TransactionStartTime  \
# 0             airtime  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z
# 1  financial_services  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z
# 2             airtime  ChannelId_3    500.0    500  2018-11-15T02:44:21Z
# 3        utility_bill  ChannelId_3  20000.0  21800  2018-11-15T03:32:55Z
# 4  financial_services  ChannelId_2   -644.0    644  2018-11-15T03:34:21Z
#
#    PricingStrategy  FraudResult
# 0                2            0
# 1                2            0
# 2                2            0
# 3                2            0
# 4                2            0

# %%
df_fe.columns
# Out:
# Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult'],
#       dtype='object')

# %% [markdown]
# Create Aggregate Features

# %%
agg_feature = df_fe.groupby('CustomerId')['Amount'].agg(['sum','mean','count','std','min','max']).reset_index()
agg_feature.columns = ['CustomerId','Amount_sum','Amount_mean','Amount_count','Amount_std','Amount_min','Amount_max']
agg_feature.head()
# Out:
#         CustomerId  Amount_sum   Amount_mean  Amount_count   Amount_std  \
# 0     CustomerId_1    -10000.0 -10000.000000             1          NaN
# 1    CustomerId_10    -10000.0 -10000.000000             1          NaN
# 2  CustomerId_1001     20000.0   4000.000000             5  6558.963333
# 3  CustomerId_1002      4225.0    384.090909            11   560.498966
# 4  CustomerId_1003     20000.0   3333.333333             6  6030.478146
#
#    Amount_min  Amount_max
# 0    -10000.0    -10000.0
# 1    -10000.0    -10000.0
# 2     -5000.0     10000.0
# 3       -75.0      1500.0
# 4     -5000.0     10000.0

# %%
df_fe = df_fe.merge(agg_feature, on='CustomerId', how='left')

# %%
agg_feature.tail()
# Out:
#           CustomerId  Amount_sum  Amount_mean  Amount_count    Amount_std  \
# 3737  CustomerId_992     20000.0  3333.333333             6   6088.240030
# 3738  CustomerId_993     20000.0  4000.000000             5   6745.368782
# 3739  CustomerId_994    543873.0  5384.881188           101  14800.656784
# 3740  CustomerId_996    139000.0  8176.470588            17   4433.329648
# 3741  CustomerId_998    100000.0  4545.454545            22   6775.145563
#
#       Amount_min  Amount_max
# 3737     -5000.0     10000.0
# 3738     -5000.0     10000.0
# 3739     -5000.0     90000.0
# 3740     -5000.0     10000.0
# 3741     -5000.0     10000.0

# %% [markdown]
# Extract Features

# %%
df_fe['TransactionStartTime'] = pd.to_datetime(df['TransactionStartTime'])

# %%
df_fe['TransactionHour'] = df_fe['TransactionStartTime'].dt.hour
df_fe['TransactionDay'] = df_fe['TransactionStartTime'].dt.day
df_fe['TransactionMonth'] = df_fe['TransactionStartTime'].dt.month
df_fe['TransactionYear'] = df_fe['TransactionStartTime'].dt.year

# %%
df_fe.head(20)
# Out:
#            TransactionId         BatchId       AccountId       SubscriptionId  \
# 0    TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1    TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2    TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3      TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4    TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
# 5    TransactionId_23223   BatchId_25954  AccountId_1078  SubscriptionId_4238
# 6   TransactionId_118063  BatchId_118460  AccountId_2442  SubscriptionId_1980
# 7   TransactionId_100640   BatchId_38561  AccountId_4841  SubscriptionId_3829
# 8    TransactionId_51905   BatchId_93774   AccountId_272  SubscriptionId_4731
# 9   TransactionId_130161   BatchId_82409   AccountId_710   SubscriptionId_920
# 10   TransactionId_51800  BatchId_112288  AccountId_2634  SubscriptionId_3511
# 11   TransactionId_33857  BatchId_126394  AccountId_4841  SubscriptionId_3829
# 12   TransactionId_94963  BatchId_104726   AccountId_710   SubscriptionId_920
# 13  TransactionId_104687   BatchId_59433   AccountId_710   SubscriptionId_920
# 14   TransactionId_86903   BatchId_59433   AccountId_710   SubscriptionId_920
# 15  TransactionId_118831   BatchId_59433   AccountId_710   SubscriptionId_920
# 16  TransactionId_122975   BatchId_31312  AccountId_2685  SubscriptionId_4626
# 17   TransactionId_98367    BatchId_6789  AccountId_2685  SubscriptionId_4626
# 18   TransactionId_64044  BatchId_117733  AccountId_4841  SubscriptionId_3829
# 19  TransactionId_119821   BatchId_89644  AccountId_3081  SubscriptionId_4312
#
#          CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0   CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1   CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2   CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3    CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4    CustomerId_988          UGX          256  ProviderId_4   ProductId_6
# 5   CustomerId_1432          UGX          256  ProviderId_6   ProductId_3
# 6   CustomerId_2858          UGX          256  ProviderId_5   ProductId_3
# 7   CustomerId_2858          UGX          256  ProviderId_4   ProductId_6
# 8    CustomerId_598          UGX          256  ProviderId_6  ProductId_10
# 9   CustomerId_1053          UGX          256  ProviderId_1  ProductId_15
# 10  CustomerId_3052          UGX          256  ProviderId_6   ProductId_3
# 11  CustomerId_3052          UGX          256  ProviderId_4   ProductId_6
# 12  CustomerId_1053          UGX          256  ProviderId_1  ProductId_15
# 13  CustomerId_1053          UGX          256  ProviderId_3  ProductId_15
# 14  CustomerId_1053          UGX          256  ProviderId_3  ProductId_15
# 15  CustomerId_1053          UGX          256  ProviderId_3  ProductId_15
# 16  CustomerId_3105          UGX          256  ProviderId_5  ProductId_15
# 17  CustomerId_3105          UGX          256  ProviderId_6  ProductId_11
# 18  CustomerId_3105          UGX          256  ProviderId_4   ProductId_6
# 19  CustomerId_3507          UGX          256  ProviderId_5   ProductId_3
#
#        ProductCategory  ... Amount_sum  Amount_mean  Amount_count  \
# 0              airtime  ...  109921.75   923.712185           119
# 1   financial_services  ...  109921.75   923.712185           119
# 2              airtime  ...    1000.00   500.000000             2
# 3         utility_bill  ...  228727.20  6019.136842            38
# 4   financial_services  ...  228727.20  6019.136842            38
# 5              airtime  ...    2000.00  2000.000000             1
# 6              airtime  ...   93400.00  3220.689655            29
# 7   financial_services  ...   93400.00  3220.689655            29
# 8              airtime  ...    8060.00  2015.000000             4
# 9   financial_services  ...   13788.00  1969.714286             7
# 10             airtime  ...   10700.00   891.666667            12
# 11  financial_services  ...   10700.00   891.666667            12
# 12  financial_services  ...   13788.00  1969.714286             7
# 13  financial_services  ...   13788.00  1969.714286             7
# 14  financial_services  ...   13788.00  1969.714286             7
# 15  financial_services  ...   13788.00  1969.714286             7
# 16  financial_services  ...  159548.00   801.748744           199
# 17        data_bundles  ...  159548.00   801.748744           199
# 18  financial_services  ...  159548.00   801.748744           199
# 19             airtime  ...    6350.00   577.272727            11
#
#       Amount_std  Amount_min  Amount_max  TransactionHour  TransactionDay  \
# 0    3042.294251     -5000.0     20000.0                2              15
# 1    3042.294251     -5000.0     20000.0                2              15
# 2       0.000000       500.0       500.0                2              15
# 3   17169.241610    -10000.0    100000.0                3              15
# 4   17169.241610    -10000.0    100000.0                3              15
# 5            NaN      2000.0      2000.0                3              15
# 6    5493.966126     -5000.0     20000.0                3              15
# 7    5493.966126     -5000.0     20000.0                3              15
# 8    3342.588817      -140.0      7000.0                4              15
# 9    1911.444629       -12.0      4000.0                4              15
# 10    691.777465       -75.0      1500.0                4              15
# 11    691.777465       -75.0      1500.0                4              15
# 12   1911.444629       -12.0      4000.0                4              15
# 13   1911.444629       -12.0      4000.0                4              15
# 14   1911.444629       -12.0      4000.0                4              15
# 15   1911.444629       -12.0      4000.0                4              15
# 16    713.068993      -100.0      3000.0                4              15
# 17    713.068993      -100.0      3000.0                4              15
# 18    713.068993      -100.0      3000.0                4              15
# 19    780.369668       -50.0      2000.0                4              15
#
#     TransactionMonth  TransactionYear
# 0                 11             2018
# 1                 11             2018
# 2                 11             2018
# 3                 11             2018
# 4                 11             2018
# 5                 11             2018
# 6                 11             2018
# 7                 11             2018
# 8                 11             2018
# 9                 11             2018
# 10                11             2018
# 11                11             2018
# 12                11             2018
# 13                11             2018
# 14                11             2018
# 15                11             2018
# 16                11             2018
# 17                11             2018
# 18                11             2018
# 19                11             2018
#
# [20 rows x 26 columns]

# %%
target_col = 'FraudResult'
y = df_fe[target_col]
x = df_fe.drop(columns=[target_col,'TransactionId','BatchId','AccountId','SubscriptionId','TransactionStartTime'])

# %%
x.head()
# Out:
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory    ChannelId   Amount  Value  PricingStrategy  \
# 0             airtime  ChannelId_3   1000.0   1000                2
# 1  financial_services  ChannelId_2    -20.0     20                2
# 2             airtime  ChannelId_3    500.0    500                2
# 3        utility_bill  ChannelId_3  20000.0  21800                2
# 4  financial_services  ChannelId_2   -644.0    644                2
#
#    Amount_sum  Amount_mean  Amount_count    Amount_std  Amount_min  \
# 0   109921.75   923.712185           119   3042.294251     -5000.0
# 1   109921.75   923.712185           119   3042.294251     -5000.0
# 2     1000.00   500.000000             2      0.000000       500.0
# 3   228727.20  6019.136842            38  17169.241610    -10000.0
# 4   228727.20  6019.136842            38  17169.241610    -10000.0
#
#    Amount_max  TransactionHour  TransactionDay  TransactionMonth  \
# 0     20000.0                2              15                11
# 1     20000.0                2              15                11
# 2       500.0                2              15                11
# 3    100000.0                3              15                11
# 4    100000.0                3              15                11
#
#    TransactionYear
# 0             2018
# 1             2018
# 2             2018
# 3             2018
# 4             2018

# %% [markdown]
# Encode Categorical Variables: Apply One-Hot Encoding

# %%
cat_cols = [  'CurrencyCode','CountryCode','ProviderId','ProductId','ProductCategory','ChannelId','PricingStrategy']
num_cols = list(agg_feature.columns)

# %%
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), 
    ('encoder', OneHotEncoder(
        handle_unknown='ignore',
        min_frequency=0.01
    ))
])

# %% [markdown]
# Standardize Numerical Features

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ]
)

# %%
customer_df = agg_feature.shape
customer_df
# Out:
# (3742, 7)

# %%
x_processed = preprocessor.fit_transform(x)
print("preprocessed feature matrix shape:", x_processed.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 x_processed = preprocessor.fit_transform(x)
#       2 print("preprocessed feature matrix shape:", x_processed.shape)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:999, in ColumnTransformer.fit_transform(self, X, y, **params)
#     996 else:
#     997     routed_params = self._get_empty_routing()
# --> 999 result = self._call_func_on_transformers(
#    1000     X,
#    1001     y,
#    1002     _fit_transform_one,
#    1003     column_as_labels=False,
#    1004     routed_params=routed_params,
#    1005 )
#    1007 if not result:
#    1008     self._update_fitted_transformers([])
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:901, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
#    (...)    898             )
#     899         )
# --> 901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#     904     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\pipeline.py:677, in Pipeline.fit_transform(self, X, y, **params)
#     638 """Fit the model and transform with the final estimator.
#     639
#     640 Fit all the transformers one after the other and sequentially transform
#    (...)    674     Transformed samples.
#     675 """
#     676 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 677 Xt = self._fit(X, y, routed_params)
#     679 last_step = self._final_estimator
#     680 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\pipeline.py:547, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     540 # Fit or load from cache the current transformer
#     541 step_params = self._get_metadata_for_step(
#     542     step_idx=step_idx,
#     543     step_params=routed_params[name],
#     544     all_params=raw_params,
#     545 )
# --> 547 X, fitted_transformer = fit_transform_one_cached(
#     548     cloned_transformer,
#     549     X,
#     550     y,
#     551     weight=None,
#     552     message_clsname="Pipeline",
#     553     message=self._log_message(step_idx),
#     554     params=step_params,
#     555 )
#     556 # Replace the transformer of the step with the fitted
#     557 # transformer. This is necessary when loading the transformer
#     558 # from the cache.
#     559 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\impute\_base.py:447, in SimpleImputer.fit(self, X, y)
#     429 @_fit_context(prefer_skip_nested_validation=True)
#     430 def fit(self, X, y=None):
#     431     """Fit the imputer on `X`.
#     432
#     433     Parameters
#    (...)    445         Fitted estimator.
#     446     """
# --> 447     X = self._validate_input(X, in_fit=True)
#     449     # default fill_value is 0 for numerical input and "missing_value"
#     450     # otherwise
#     451     if self.fill_value is None:
#
# File c:\Users\arwa\credit-risk-model\venv\Lib\site-packages\sklearn\impute\_base.py:372, in SimpleImputer._validate_input(self, X, in_fit)
#     366 if "could not convert" in str(ve):
#     367     new_ve = ValueError(
#     368         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     369             self.strategy, ve
#     370         )
#     371     )
# --> 372     raise new_ve from None
#     373 else:
#     374     raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'CustomerId_4406'

# %%
x_final = pd.DataFrame(x_processed, 
    columns=num_cols, 
    index=x.index  
)

# %% [markdown]
# Save the processed data

# %%
features_path = '../data/processed/customer_features.csv'
x_final.to_csv(features_path)

# %% [markdown]
# WoE and IV using xverse

# %%
x_woe_input = x[cat_cols]

woe = WOE()
woe.fit(x_woe_input, y)

# %%
print("WOE values")
print(woe.woe_df.head())

# %%
print("information value(IV)")
print(woe.iv_df)

# %%
x_cat_woe = woe.transform(x_woe_input,y)
print("woe transformed shape:",x_cat_woe.shape)
